# %% [markdown]
# <a href="https://colab.research.google.com/github/raphaelz306/DMC_Course/blob/main/TrabajoIntegrador.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Lectura de data
DATA = pd.read_csv('/content/DATA.csv')

# %%
#Revisión de data
DATA.head()
# Out:
#    num_documento                 nombre_completo  edad  Nro_reclamos_tri  \
# 0            NaN                             NaN   NaN               NaN
# 1       208265.0  JOSE MERCEDES PASACHE CHIROQUE  50.0               4.0
# 2        43839.0        MARINA BARBARAN LA TORRE  43.0               0.0
# 3       124251.0       CARLOS CHARLY PRADO LOPEZ  24.0               0.0
# 4       119074.0      ENITH SONIA GONZALES LOPEZ  29.0               0.0
#
#   motivo_salida       sexo est_civil nse_agrup ind_critico  \
# 0           NaN        NaN       NaN       NaN         NaN
# 1           NaN  MASCULINO    CASADO         B          NO
# 2           NaN   FEMENINO   SOLTERO         B          NO
# 3           NaN  MASCULINO   SOLTERO         B          NO
# 4           NaN   FEMENINO   SOLTERO         B          NO
#
#                  region  ind_tenencia_hijos ext_des_calificacion_sbs  \
# 0                   NaN                 NaN                      NaN
# ...
